# %%
import pandas as pd
from sqlalchemy import create_engine
password = 'sqL7910253'

# %%
yelp_json = '../yelp_ETL_data/business.json'
yelp_df = pd.read_json(yelp_json, lines=True)
yelp_df.head()
# Out:
#                           address  \
# 0     2818 E Camino Acequia Drive
# 1            30 Eglinton Avenue W
# 2       10110 Johnston Rd, Ste 15
# 3   15655 W Roosevelt St, Ste 237
# 4  4209 Stuart Andrew Blvd, Ste F
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
# 2  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 3                                               None  xvX2CttrVhyG2z1dFg_0xw
# 4  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
#
#                                           categories         city  \
# 0                                  Golf, Active Life      Phoenix
# 1  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
# 2                  Sushi Bars, Restaurants, Japanese    Charlotte
# 3                      Insurance, Financial Services     Goodyear
# 4  Plumbing, Shopping, Local Services, Home Servi...    Charlotte
#
#                                                hours  is_open   latitude  \
# 0                                               None        0  33.522143
# 1  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...        1  43.605499
# 2  {'Monday': '17:30-21:30', 'Wednesday': '17:30-...        1  35.092564
# 3  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1  33.455613
# 4  {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...        1  35.190012
#
#     longitude                             name postal_code  review_count  \
# 0 -112.018481       Arizona Biltmore Golf Club       85016             5
# 1  -79.652289       Emerald Chinese Restaurant     L5R 3E7           128
# 2  -80.859132      Musashi Japanese Restaurant       28210           170
# 3 -112.395596  Farmers Insurance - Paul Lorenz       85338             3
# 4  -80.887223              Queen City Plumbing       28217             4
#
#    stars state
# 0    3.0    AZ
# 1    2.5    ON
# 2    4.0    NC
# 3    5.0    AZ
# 4    4.0    NC

# %%
attributes_df = yelp_df['attributes'].apply(pd.Series)

# %%
caters_df = attributes_df['Caters']
caters_df.head()
# Out:
# 0      NaN
# 1     True
# 2    False
# 3      NaN
# 4      NaN
# Name: Caters, dtype: object

# %%
cleaned_df = pd.concat([yelp_df.drop(['attributes'], axis=1), caters_df], axis=1)
cleaned_df = cleaned_df[['business_id', 'name', 'address', 'state', 'postal_code', 'Caters', 'stars', 'review_count']]
cleaned_df.rename(columns={'postal_code':'zip_code','Caters':'has_catering'}, inplace=True)
cleaned_df.head()
# Out:
#               business_id                             name  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
#
#                           address state zip_code has_catering  stars  \
# 0     2818 E Camino Acequia Drive    AZ    85016          NaN    3.0
# 1            30 Eglinton Avenue W    ON  L5R 3E7         True    2.5
# 2       10110 Johnston Rd, Ste 15    NC    28210        False    4.0
# 3   15655 W Roosevelt St, Ste 237    AZ    85338          NaN    5.0
# 4  4209 Stuart Andrew Blvd, Ste F    NC    28217          NaN    4.0
#
#    review_count
# 0             5
# 1           128
# 2           170
# 3             3
# 4             4

# %%
type(cleaned_df.at[2,'has_catering'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-df1e49da0dbb> in <module>
# ----> 1 type(cleaned_df.at[2,'has_catering'])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    2140
#    2141         key = self._convert_key(key)
# -> 2142         return self.obj._get_value(*key, takeable=self._takeable)
#    2143
#    2144     def __setitem__(self, key, value):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _get_value(self, index, col, takeable)
#    2537
#    2538         try:
# -> 2539             return engine.get_value(series._values, index)
#    2540         except (TypeError, ValueError):
#    2541
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 2

# %%
businesses_df = cleaned_df.loc[(cleaned_df['has_catering'] == 'True') | (cleaned_df['has_catering'] == 'False')]
businesses_df.head(100)
# Out:
#                 business_id                                 name  \
# 1    QXAEGFB4oINsVuTFxEYKFQ           Emerald Chinese Restaurant
# 2    gnKjwL_1w79qoiV3IC_xQQ          Musashi Japanese Restaurant
# 17   PZ-LZzSlhSe9utkQYU8pFg           Carluccio's Tivoli Gardens
# 25   tstimHoMcYbkSC4eBA1wEg  Maria's Mexican Restaurant & Bakery
# 29   NDuUMJfrWk52RA-H-OtrpA                       Bolt Fresh Bar
# 32   SP_YXIEwkFPPl_9anCYmpQ                The Steady Cafe & Bar
# 33   irft4YkdNsww4DNf_Aftew                So Cool Frozen Yogurt
# 47   GWO87Y-IqL54_Ijx6hTYAQ             Bruster's Real Ice Cream
# 50   mlHC2XcU9Bows6cnYEmRgg                   Mad Crush Wine Bar
# 53   q2KtxnPa6rPSpAlMbg9l8g                  Nothing Bundt Cakes
# 58   _J_x_RaYTqAqAuCwgRhnRQ                          Kabob House
# 61   6l00a9Gkxkcp_y-GPjYBiw                     J's Fish & Chips
# 66   dQj5DLZjeDK3KFysh1SYOQ                               Apteka
# 71   9UTpmQ4OhX5jNFUIu7dPPQ             Buk Chang Dong Soon Tofu
# 73   v-scZMU6jhnmV955RSzGJw                    No. 1 Sushi Sushi
# 75   kANF0dbeoW34s2vwh6Umfw                          Dairy Queen
# 77   KFbUQ-RR2UOV62Ep7WnXHw                 Westwood Bar & Grill
# 78   44YFU284Z3KDEy25QyVoUw         Nee House Chinese Restaurant
# 81   eXgDqKD7-sojyzh6q7PJ4g                    The Sweet Gallery
# 92   SWX0K1dpy4fcRq-ktZxmCg                   Bistro des Moulins
# 96   NPHZkn1e-tSJAbo8Zm9rYw                     Burrito Bandidos
# 113  7aLkFEBnL1LJmQdcuaovuQ                     Ohio Beer Garden
# 115  qJeSjOMgWB3er3UXG33ZVw                            Carl's Jr
# 116  gyFYZV4b_9TxG1ulQNi0Ig                 Paramount Fine Foods
# 120  0lFAD4CuWcQVl9u3-lRaCQ               Cruisers Bar and Grill
# 128  sKhDrZFCJqfRNylkHrIDsQ                            Starbucks
# 133  ysfeDcLAYk_MVzfBmyiSTg           Vals Getaway DES Cafeteria
# 135  bJP4l_BGq2CudEu0m-wNjg             Artisan Fine Dining Room
# 137  Q1GhjqlLENaT383k9Ex5wg                          Daily Donut
# 140  r8764MtYyt8JhxMvrfM_xQ                           Vintage 95
# ..                      ...                                  ...
# 305  pUihHVilZtpZz4FApnOvtA                             Mr Combo
# 307  Qb4sJ4ssSX1clY2wEAOmsA                         Trader Joe's
# 309  LF66oShCh30k5NOV6pPJTQ                         Flyjin Caf̩
# 337  ItmLljzhwhuyyvekNs4Ymg                   Jersey Mike's Subs
# 343  jX9DocoiY4Bo9EUkaTSqvg                            China AAA
# 346  ecJri9ozyke4dOCWulZiRQ                      Nishikawa Ramen
# 356  mofOjB6flg-eAWOFbOkHfQ                     ChinaTown Buffet
# 362  6gorEMxDpiCTUmLXI5DCoQ                      Tandoori Xpress
# 367  trMrmg0EKcxEYAkqLBbRMA                 Piggly's At the Fair
# 374  QZ4GFIArBMGolsVi0XHgcA                   Golden Flower Cafe
# 377  F6c3D1o9Z4Tl6cDorb3WgA                         Hello Bistro
# 384  CodoVn98WzIP2_NC18NuCw         Chez ma Grosse Truie Ch̩rie
# 392  Ykn6eHLY8vPHuUH7UQrvxw                     La Barista Caf̩
# 406  j9YFHVQqxM_qKHIc4nck-A                 Wong's Asian Cuisine
# 407  KAhavksKQwKbMzZHiNOyOQ                    Gino's Restaurant
# 410  UZCfJ29B4MRIS3igABE_Ew          Gandhi International Market
# 411  nwxF9EKLOCpkScMF2utHDw                        Ben & Jerry's
# 414  i_0rSAui4zaz4ydVaOZ6bQ             Marcello's Market & Deli
# 417  L6R2Op88NkoG1EGxlVvdRQ            Bread & Roses Bakery Cafe
# 418  xHZmM-kGXqOfmQNTm0T05g             Circles Grill and Market
# 424  mQkVFNSDpD4frPUMycVoWw       Solstice Restaurant & Wine Bar
# 426  Hdzo5ggPswyv-8ZlW0PVLw                            Gelato 64
# 428  nm5yx8yvJNJYVjaRPwjnsw                               Misaki
# 431  m4DwPVxmFDQE_FnGIOa3cQ                   Sunny China Buffet
# 432  9VSPMQXgPdJ4rNgBPLJZ1A                Rosso Coffee Roasters
# 434  wdsGP5rJinx0J5GcGzPQUw                      TJ's Steakhouse
# 435  UPh90LM8UMnVFQP6NGktrA                    Cakes On the Move
# 439  hXzoNgpkC86K_Jfg_zMHvA                               PHO KC
# 446  dtpFxDbBTBl90NyttDqoMg               2 Girls' Cafe & Bakery
# 452  NX1281ugzs2navHAX5X9cQ                           Cha Me Cha
#
#                                        address state zip_code has_catering  \
# 1                         30 Eglinton Avenue W    ON  L5R 3E7         True
# 2                    10110 Johnston Rd, Ste 15    NC    28210        False
# 17                1775 E Tropicana Ave, Ste 29    NV    89119         True
# 25                       6055 E Lake Mead Blvd    NV    89156        False
# 29                         1170 Queen Street W    ON  M6J 1J5        False
# 32                         1051 Bloor Street W    ON  M6H 1M4         True
# 33                         9020 B Albemarle Rd    NC    28227        False
# 47                                709 W Ray Rd    AZ    85233         True
# 50                          582 College Street    ON  M6G 1B3        False
# 53              17025 N Scottsdale Rd, Ste 110    AZ    85255         True
# 58                    6432 E Independence Blvd    NC    28212         True
# 61                 17205 Leslie Street, Unit 2    ON  L3Y 8Y8         True
# 66                               4606 Penn Ave    PA    15224         True
# 71                      3085 Hurontario Street    ON      L5A        False
# 73                               436 Market St    PA    15222         True
# 75                     6125 Spring Mountain Rd    NV    89146        False
# 77                        825 Commonwealth Ave    PA    15122         True
# 78                  13843 N Tatum Blvd, Ste 15    AZ    85032         True
# 81                           350 Bering Avenue    ON  M8Z 3A9         True
# 92                           10897 Rue du Pont    QC  H2B 2H3        False
# 96                         1614 Queen Street E    ON  M4L 1G4        False
# 113                    402 Great Northern Blvd    OH    44070        False
# 115                           309 50 Avenue SW    AB  T2S 1H3        False
# 116                    165 East Liberty Street    ON  M6K 3K4         True
# 120                    6625 Dean Memorial Pkwy    OH    44236        False
# 128        1990 Village Center Circle, Suite 1    NV    89134        False
# 133                           1789 W Jefferson    AZ    85007        False
# 135           Artisan Hotel, 1501 W Sahara Ave    NV    89102        False
# 137             9133 W Thunderbird Rd, Ste 107    AZ    85381        False
# 140                                95 W Boston    AZ    85225        False
# ..                                         ...   ...      ...          ...
# 305                      568 Sheppard Avenue W    ON  M3H 2R9         True
# 307                   2716 N Green Valley Pkwy    NV    89014        False
# 309            417 Rue Saint-Pierre, Suite 101    QC      H2Y        False
# 337                            1601 Deming Way    WI    53562         True
# 343                        10624 S Eastern Ave    NV    89052         True
# 346                              1909 E Ray Rd    AZ    85225         True
# 356                        713 W Marketview Dr    IL    61822        False
# 362             220 Boulevard de la Concorde E    QC  H7G 2E1         True
# 367                          1633 S Stapley Dr    AZ    85204         True
# 374                   1 Spadina Road, Suite 11    ON  L4B 2Y1         True
# 377                        701 Providence Blvd    PA    15237         True
# 384                         1801 Rue Ontario E    QC  H2K 1T5        False
# 392                       22 St Clair Avenue E    ON      M4T        False
# 406                    2173 Lawrence Avenue  E    ON  M1P 2P5         True
# 407                               540 State St    WI    53703         True
# 410                9630-G University City Blvd    NC    28213        False
# 411                           7800 Fairview Rd    NC    28226         True
# 414  40 King Street W, Scotia plaza Food Court    ON  M5H 1B6         True
# 417                        2901 Bayview Avenue    ON  M2K 2S3        False
# 418                        8129 Ardrey Kell Rd    NC    28277        False
# 424                      1801 Lakeshore Road W    ON  L5J 1J6         True
# 426                           2095 N Dobson Rd    AZ    85224         True
# 428                      860 Saw Mill Run Blvd    PA    15226         True
# 431                              1703 Philo Rd    IL    61802        False
# 432                           425 11 Avenue SE    AB  T2G 0Y4         True
# 434                           3000 Paradise Rd    NV    89109        False
# 435                      1211 Santa Helena Ave    NV    89002         True
# 439                  18555 N 59th Ave, Ste 130    AZ    85308        False
# 446                             3707 Darrow Rd    OH    44224         True
# 452              8333 Kennedy Road, Suite 1078    ON  L3R 1J5        False
#
#      stars  review_count
# 1      2.5           128
# 2      4.0           170
# 17     4.0            40
# 25     4.5           184
# 29     3.0            57
# 32     3.5            29
# 33     4.5             6
# 47     4.5            57
# 50     4.0             9
# 53     4.0           174
# 58     3.0            15
# 61     4.5            12
# 66     4.5           242
# 71     4.0           103
# 73     4.5           106
# 75     2.0            33
# 77     3.0             5
# 78     3.5           269
# 81     4.0            20
# 92     3.5             3
# 96     3.5            43
# 113    4.0             8
# 115    3.5             6
# 116    2.0            40
# 120    3.5            12
# 128    4.0            76
# 133    3.0            14
# 135    2.0             3
# 137    4.5            33
# 140    4.0           320
# ..     ...           ...
# 305    4.0            15
# 307    4.5           196
# 309    4.5            17
# 337    4.0            20
# 343    4.5           149
# 346    4.0           427
# 356    2.5            72
# 362    2.5             8
# 367    3.0            85
# 374    3.5            31
# 377    3.5            75
# 384    3.5            30
# 392    3.0             4
# 406    4.0            22
# 407    3.5            38
# 410    2.0            11
# 411    3.5            19
# 414    3.5             7
# 417    3.0            23
# 418    4.0            27
# 424    4.0            34
# 426    4.0           140
# 428    3.0            44
# 431    3.5            15
# 432    3.5            15
# 434    4.0            60
# 435    5.0            57
# 439    4.5            96
# 446    4.0            16
# 452    3.0           293
#
# [100 rows x 8 columns]

# %%
income_csv = '../yelp_ETL_data/MedianZIP.csv'
income_df = pd.read_csv(income_csv)

# %%
income_df = income_df[['Zip','Median']].rename(columns={'Zip':'zip_code','Median':'median_income'})
income_df.head()
# Out:
#    zip_code median_income
# 0      1001        56,663
# 1      1002        49,853
# 2      1003        28,462
# 3      1005        75,423
# 4      1007        79,076

# %%
connection_string = f"root:{password}@localhost/yelp_delivery_db"
engine = create_engine(f"mysql://{connection_string}")

# %%
businesses_df.to_sql(name='businesses', con=engine, if_exists='replace', index=False)
