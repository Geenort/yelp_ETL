# %%
import pandas as pd
from sqlalchemy import create_engine
password = 'sqL7910253'

# %%
# Read in business data from JSON, into a Dataframe
yelp_json = '../yelp_ETL_data/business.json'
yelp_df = pd.read_json(yelp_json, lines=True)
yelp_df.head()
# Out:
#                           address  \
# 0     2818 E Camino Acequia Drive
# 1            30 Eglinton Avenue W
# 2       10110 Johnston Rd, Ste 15
# 3   15655 W Roosevelt St, Ste 237
# 4  4209 Stuart Andrew Blvd, Ste F
#
#                                           attributes             business_id  \
# 0                           {'GoodForKids': 'False'}  1SWheh84yJXfytovILXOAQ
# 1  {'RestaurantsReservations': 'True', 'GoodForMe...  QXAEGFB4oINsVuTFxEYKFQ
# 2  {'GoodForKids': 'True', 'NoiseLevel': 'u'avera...  gnKjwL_1w79qoiV3IC_xQQ
# 3                                               None  xvX2CttrVhyG2z1dFg_0xw
# 4  {'BusinessAcceptsBitcoin': 'False', 'ByAppoint...  HhyxOkGAM07SRYtlQ4wMFQ
#
#                                           categories         city  \
# 0                                  Golf, Active Life      Phoenix
# 1  Specialty Food, Restaurants, Dim Sum, Imported...  Mississauga
# 2                  Sushi Bars, Restaurants, Japanese    Charlotte
# 3                      Insurance, Financial Services     Goodyear
# 4  Plumbing, Shopping, Local Services, Home Servi...    Charlotte
#
#                                                hours  is_open   latitude  \
# 0                                               None        0  33.522143
# 1  {'Monday': '9:0-0:0', 'Tuesday': '9:0-0:0', 'W...        1  43.605499
# 2  {'Monday': '17:30-21:30', 'Wednesday': '17:30-...        1  35.092564
# 3  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...        1  33.455613
# 4  {'Monday': '7:0-23:0', 'Tuesday': '7:0-23:0', ...        1  35.190012
#
#     longitude                             name postal_code  review_count  \
# 0 -112.018481       Arizona Biltmore Golf Club       85016             5
# 1  -79.652289       Emerald Chinese Restaurant     L5R 3E7           128
# 2  -80.859132      Musashi Japanese Restaurant       28210           170
# 3 -112.395596  Farmers Insurance - Paul Lorenz       85338             3
# 4  -80.887223              Queen City Plumbing       28217             4
#
#    stars state
# 0    3.0    AZ
# 1    2.5    ON
# 2    4.0    NC
# 3    5.0    AZ
# 4    4.0    NC

# %%
# Flatten dictionaries in 'attributes' column into separate columns
attributes_df = yelp_df['attributes'].apply(pd.Series)
attributes_df.head()
# Out:
#   GoodForKids RestaurantsReservations  \
# 0       False                     NaN
# 1        True                    True
# 2        True                    True
# 3         NaN                     NaN
# 4         NaN                     NaN
#
#                                          GoodForMeal  \
# 0                                                NaN
# 1  {'dessert': False, 'latenight': False, 'lunch'...
# 2  {'dessert': False, 'latenight': False, 'lunch'...
# 3                                                NaN
# 4                                                NaN
#
#                                      BusinessParking Caters  NoiseLevel  \
# 0                                                NaN    NaN         NaN
# 1  {'garage': False, 'street': False, 'validated'...   True     u'loud'
# 2  {'garage': False, 'street': False, 'validated'...  False  u'average'
# 3                                                NaN    NaN         NaN
# 4                                                NaN    NaN         NaN
#
#   RestaurantsTableService RestaurantsTakeOut RestaurantsPriceRange2  \
# 0                     NaN                NaN                    NaN
# 1                    True               True                      2
# 2                    True               True                      2
# 3                     NaN                NaN                    NaN
# 4                     NaN                NaN                    NaN
#
#   OutdoorSeating            ...            BYOBCorkage DriveThru Smoking  \
# 0            NaN            ...                    NaN       NaN     NaN
# 1          False            ...                    NaN       NaN     NaN
# 2          False            ...                    NaN       NaN     NaN
# 3            NaN            ...                    NaN       NaN     NaN
# 4            NaN            ...                    NaN       NaN     NaN
#
#   AgesAllowed HairSpecializesIn Corkage BYOB DietaryRestrictions Open24Hours  \
# 0         NaN               NaN     NaN  NaN                 NaN         NaN
# 1         NaN               NaN     NaN  NaN                 NaN         NaN
# 2         NaN               NaN     NaN  NaN                 NaN         NaN
# 3         NaN               NaN     NaN  NaN                 NaN         NaN
# 4         NaN               NaN     NaN  NaN                 NaN         NaN
#
#   RestaurantsCounterService
# 0                       NaN
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4                       NaN
#
# [5 rows x 39 columns]

# %%
# Pull just the 'Caters' column
caters_df = attributes_df['Caters']
caters_df.head()
# Out:
# 0      NaN
# 1     True
# 2    False
# 3      NaN
# 4      NaN
# Name: Caters, dtype: object

# %%
# Concatenate 'Caters' column to original DF along column axis, and drop original 'attributes' column
cleaned_df = pd.concat([yelp_df.drop(['attributes'], axis=1), caters_df], axis=1)

# Select only the necessary columns and rename
cleaned_df = cleaned_df[['business_id', 'name', 'address', 'state', 'postal_code', 'Caters', 'stars', 'review_count']]
cleaned_df.rename(columns={'postal_code':'zip_code','Caters':'has_catering'}, inplace=True)
cleaned_df.head()
# Out:
#               business_id                             name  \
# 0  1SWheh84yJXfytovILXOAQ       Arizona Biltmore Golf Club
# 1  QXAEGFB4oINsVuTFxEYKFQ       Emerald Chinese Restaurant
# 2  gnKjwL_1w79qoiV3IC_xQQ      Musashi Japanese Restaurant
# 3  xvX2CttrVhyG2z1dFg_0xw  Farmers Insurance - Paul Lorenz
# 4  HhyxOkGAM07SRYtlQ4wMFQ              Queen City Plumbing
#
#                           address state zip_code has_catering  stars  \
# 0     2818 E Camino Acequia Drive    AZ    85016          NaN    3.0
# 1            30 Eglinton Avenue W    ON  L5R 3E7         True    2.5
# 2       10110 Johnston Rd, Ste 15    NC    28210        False    4.0
# 3   15655 W Roosevelt St, Ste 237    AZ    85338          NaN    5.0
# 4  4209 Stuart Andrew Blvd, Ste F    NC    28217          NaN    4.0
#
#    review_count
# 0             5
# 1           128
# 2           170
# 3             3
# 4             4

# %%
# Trim DF to only include rows with True or False in 'has_catering' column
cleaned_df = cleaned_df.loc[(cleaned_df['has_catering'] == 'True') | (cleaned_df['has_catering'] == 'False')]
cleaned_df.head()
# Out:
#                business_id                                 name  \
# 1   QXAEGFB4oINsVuTFxEYKFQ           Emerald Chinese Restaurant
# 2   gnKjwL_1w79qoiV3IC_xQQ          Musashi Japanese Restaurant
# 17  PZ-LZzSlhSe9utkQYU8pFg           Carluccio's Tivoli Gardens
# 25  tstimHoMcYbkSC4eBA1wEg  Maria's Mexican Restaurant & Bakery
# 29  NDuUMJfrWk52RA-H-OtrpA                       Bolt Fresh Bar
#
#                          address state zip_code has_catering  stars  \
# 1           30 Eglinton Avenue W    ON  L5R 3E7         True    2.5
# 2      10110 Johnston Rd, Ste 15    NC    28210        False    4.0
# 17  1775 E Tropicana Ave, Ste 29    NV    89119         True    4.0
# 25         6055 E Lake Mead Blvd    NV    89156        False    4.5
# 29           1170 Queen Street W    ON  M6J 1J5        False    3.0
#
#     review_count
# 1            128
# 2            170
# 17            40
# 25           184
# 29            57

# %%
# Remove rows with meaningless alphanumeric zip_code values using regex and ~ bitwise inversion/complement operator
businesses_df = cleaned_df[~cleaned_df['zip_code'].str.contains("[a-zA-Z]")]
businesses_df.head()
# Out:
#                business_id                                 name  \
# 2   gnKjwL_1w79qoiV3IC_xQQ          Musashi Japanese Restaurant
# 17  PZ-LZzSlhSe9utkQYU8pFg           Carluccio's Tivoli Gardens
# 25  tstimHoMcYbkSC4eBA1wEg  Maria's Mexican Restaurant & Bakery
# 33  irft4YkdNsww4DNf_Aftew                So Cool Frozen Yogurt
# 47  GWO87Y-IqL54_Ijx6hTYAQ             Bruster's Real Ice Cream
#
#                          address state zip_code has_catering  stars  \
# 2      10110 Johnston Rd, Ste 15    NC    28210        False    4.0
# 17  1775 E Tropicana Ave, Ste 29    NV    89119         True    4.0
# 25         6055 E Lake Mead Blvd    NV    89156        False    4.5
# 33           9020 B Albemarle Rd    NC    28227        False    4.5
# 47                  709 W Ray Rd    AZ    85233         True    4.5
#
#     review_count
# 2            170
# 17            40
# 25           184
# 33             6
# 47            57

# %%
# Read in income data from CSV, into a DataFrame
income_csv = '../yelp_ETL_data/MedianZIP.csv'
income_df = pd.read_csv(income_csv)

# %%
# Rename columns to match business data (to match keys in SQL DB)
income_df = income_df[['Zip','Median']].rename(columns={'Zip':'zip_code','Median':'median_income'})
income_df.head()
# Out:
#    zip_code median_income
# 0      1001        56,663
# 1      1002        49,853
# 2      1003        28,462
# 3      1005        75,423
# 4      1007        79,076

# %%
# Connect to local MySQL DB, with tables already created in MySQL Workbench
connection_string = f"root:{password}@localhost/yelp_delivery_db?charset=utf8mb4"
engine = create_engine(f"mysql://{connection_string}")

# %%
engine.table_names()
# Out:
# ['businesses', 'median_income']

# %%
# Replace tables in DB with DataFrames
businesses_df.to_sql(name='businesses', con=engine, if_exists='replace', index=False)
income_df.to_sql(name='median_income', con=engine, if_exists='replace', index=False)

# %%
# Confirm DFs have been added to sql db
pd.read_sql_query('SELECT * from businesses', con=engine).head()
# Out:
#               business_id                                 name  \
# 0  gnKjwL_1w79qoiV3IC_xQQ          Musashi Japanese Restaurant
# 1  PZ-LZzSlhSe9utkQYU8pFg           Carluccio's Tivoli Gardens
# 2  tstimHoMcYbkSC4eBA1wEg  Maria's Mexican Restaurant & Bakery
# 3  irft4YkdNsww4DNf_Aftew                So Cool Frozen Yogurt
# 4  GWO87Y-IqL54_Ijx6hTYAQ             Bruster's Real Ice Cream
#
#                         address state zip_code has_catering  stars  \
# 0     10110 Johnston Rd, Ste 15    NC    28210        False    4.0
# 1  1775 E Tropicana Ave, Ste 29    NV    89119         True    4.0
# 2         6055 E Lake Mead Blvd    NV    89156        False    4.5
# 3           9020 B Albemarle Rd    NC    28227        False    4.5
# 4                  709 W Ray Rd    AZ    85233         True    4.5
#
#    review_count
# 0           170
# 1            40
# 2           184
# 3             6
# 4            57

# %%
pd.read_sql_query('SELECT * from median_income', con=engine).head()
# Out:
#    zip_code median_income
# 0      1001        56,663
# 1      1002        49,853
# 2      1003        28,462
# 3      1005        75,423
# 4      1007        79,076

# %%
pd.read_sql_query('SELECT * from businesses JOIN median_income ON businesses.zip_code = median_income.zip_code LIMIT 100', con=engine).head()
# Out:
#               business_id                   name               address state  \
# 0  Ya-HZZrzMWYSBtGyLajDQg        Nathan's Famous      1038 State Rt 11    NY
# 1  Q_0eGl-aElqHKukHvmLdwA     Nelia's Smokehouse          603 Duss Ave    PA
# 2  729grSa1Wsn-hfv7D5uOxg            Pizza House      1007 Merchant St    PA
# 3  24hc1g8a7besgI0tMb3v7w  Moe's Southwest Grill  1597 Washington Pike    PA
# 4  PJcOOjebn86geLXG2qPB_Q            Giant Eagle  1025 Washington Pike    PA
#
#    zip_code has_catering  stars  review_count  zip_code median_income
# 0     12919         True    4.0             4     12919        50,833
# 1     15003         True    4.0            18     15003        39,158
# 2     15003        False    4.5            32     15003        39,158
# 3     15017         True    3.5            24     15017        55,632
# 4     15017         True    2.0             5     15017        55,632
